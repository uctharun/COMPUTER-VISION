# %% [markdown]
# <a href="https://colab.research.google.com/github/uctharun/COMPUTER-VISION/blob/main/EX%2022%20Sharpening%20of%20Image%20using%20Laplacian%20mask%20with%20positive%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-90dbc8c4-6972-4d08-b8e9-a48340e6e06c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90dbc8c4-6972-4d08-b8e9-a48340e6e06c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = next(iter(uploaded))

image = cv2.imread(filename)

print("Image loaded successfully!")
print("Image size:", image.shape)
# Out:
# Image loaded successfully!
# Image size: (800, 534, 3)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap="gray")
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# %%
laplacian_mask = np.array([
    [0, -1,  0],
    [-1,  4, -1],
    [0, -1,  0]
], dtype=np.float32)

print("Laplacian Mask with Positive Center:")
print(laplacian_mask)
# Out:
# Laplacian Mask with Positive Center:
# [[ 0. -1.  0.]
#  [-1.  4. -1.]
#  [ 0. -1.  0.]]

# %%
laplacian = cv2.filter2D(
    gray,
    cv2.CV_32F,
    laplacian_mask
)

# %%
sharpened = gray.astype(np.float32) + laplacian

sharpened = np.clip(sharpened, 0, 255).astype(np.uint8)

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.imshow(gray, cmap="gray")
plt.title("Original Grayscale Image")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(sharpened, cmap="gray")
plt.title("Laplacian Sharpened Image - Positive Center")
plt.axis("off")

plt.show()
